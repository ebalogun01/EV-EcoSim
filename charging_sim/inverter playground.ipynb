# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt

from inverter import Inverter


def plot_power_curve():
    # Plot power curve
    #     sandia efficiency model
    #     Calculate the inverter AC power without clipping
    # 
    #     :param v_dc: DC voltage input to the inverter. [V]
    #     :param p_dc: DC power input to the inverter. [W]
    #     :return: power_ac; AC power with applied limits
    voltage = ['Alice','Charles','Diane','Edward']
    power = [96, 155, 66, 272]
    dataset = list(zip(voltage,power))
    df = pd.DataFrame(data = dataset, columns=['Name', 'Number'])
    df['Number'].plot()

# %%
config = json.load(open('configs/inverter.json'))
inverter = Inverter(config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 config = json.load(open('configs/inverter.json'))
# ----> 2 inverter = Inverter(config)
#
# File ~\git-personal\EV50_cosimulation\charging_sim\inverter.py:50, in Inverter.__init__(self, node, config, controller)
#      46 self.T = self.To  # initialize at atmposheric temperature
#      48 # Load inverter config file
#      49 # TODO Update inverter config file to include better default parameters
# ---> 50 self.start = config["start_time"]
#      52 # Characteristics of the inverter in the Sandia model
#      53 self.Paco = config["Paco"]  # AC power rating of the inverter. [W]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plot_power_curve()
